# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook
import sqlite3

conn = sqlite3.connect("/Users/airkumar/jaw.db")

# %%
df = pd.read_sql_query("select * from datatable;", conn)

# %%
df['reading'] = pd.to_numeric(df['reading'])

# %%
df['recorded'] = pd.to_datetime(df['recorded'])

# %%
df.head()
# Out:
#    reading            recorded
# 0       15 2020-02-20 22:09:45
# 1       16 2020-02-20 22:09:46
# 2       17 2020-02-20 22:09:47
# 3       16 2020-02-20 22:09:48
# 4       16 2020-02-20 22:09:49

# %%
df.dtypes
# Out:
# reading              int64
# recorded    datetime64[ns]
# dtype: object

# %%
x = df['recorded']
y = df['reading']
start_date = '2020-02-23 06:00:00'
end_date = '2020-02-23 15:00:00'
xTodayFilter = x > start_date
filteredDf = df.loc[xTodayFilter]
xFilter = filteredDf['recorded']
yFilter = filteredDf['reading']
filteredDf.head()
# Out:
#        reading            recorded
# 27800       52 2020-02-23 06:50:59
# 27801       49 2020-02-23 06:51:00
# 27802       40 2020-02-23 06:51:00
# 27803       23 2020-02-23 06:51:01
# 27804      492 2020-02-23 06:51:01

# %%
plt.scatter(xFilter,yFilter,s=1)
plt.xlabel("Time")
plt.ylabel("Sensor Reading")
plt.xlim(start_date,end_date)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
